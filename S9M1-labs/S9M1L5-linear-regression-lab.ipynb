# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
fish_df = pd.read_csv('fish-data-perch-pike.csv')

# %%
sns.pairplot(fish_df)

# %%
fish_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 5 columns):
# Name          73 non-null object
# Weight_g      73 non-null float64
# Length_cm     73 non-null float64
# Height_pct    73 non-null float64
# Width_pct     73 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 3.0+ KB

# %%
ins_df = pd.read_csv('insurance.csv')

# %%
ins_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
ins_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(data=ins_df, x="age", y="charges", hue="smoker")

# %%
sns.scatterplot(data=ins_df, x="age", y="charges", hue="sex")

# %%
sns.scatterplot(data=ins_df, x="bmi", y="charges", hue="smoker")

# %%
sns.scatterplot(data=ins_df, x="bmi", y="charges", hue="sex")

# %%
df_wine = pd.read_csv('winequality-red.csv')

# %%
df_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.scatterplot(data=df_wine, x="alcohol", y="quality")

# %%
df_exp = pd.read_csv('life-expectancy.csv')

# %%
df_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
df_exp.columns = df_exp.columns.str.lower().str.replace(" ", "_")
df_exp.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy_', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles_', '_bmi_', 'under-five_deaths_', 'polio', 'total_expenditure',
#        'diphtheria_', '_hiv/aids', 'gdp', 'population',
#        '_thinness__1-19_years', '_thinness_5-9_years',
#        'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
df_exp["life_expectancy"] = df_exp.life_expectancy_
df_exp["bmi"] = df_exp._bmi_

# %%
df_exp = df_exp[["country", "year", "population", "life_expectancy", "alcohol", 
                 "bmi", "total_expenditure", "percentage_expenditure", 
                 "gdp", "schooling"]]

# %%
df_exp.columns
# Out:
# Index(['country', 'year', 'population', 'life_expectancy', 'alcohol', 'bmi',
#        'total_expenditure', 'percentage_expenditure', 'gdp', 'schooling'],
#       dtype='object')

# %%
df_exp.head()
# Out:
#        country  year  population  life_expectancy  alcohol   bmi  \
# 0  Afghanistan  2015  33736494.0             65.0     0.01  19.1
# 1  Afghanistan  2014    327582.0             59.9     0.01  18.6
# 2  Afghanistan  2013  31731688.0             59.9     0.01  18.1
# 3  Afghanistan  2012   3696958.0             59.5     0.01  17.6
# 4  Afghanistan  2011   2978599.0             59.2     0.01  17.2
#
#    total_expenditure  percentage_expenditure         gdp  schooling
# 0               8.16               71.279624  584.259210       10.1
# 1               8.18               73.523582  612.696514       10.0
# 2               8.13               73.219243  631.744976        9.9
# 3               8.52               78.184215  669.959000        9.8
# 4               7.87                7.097109   63.537231        9.5

# %%
df_exp.sort_values("bmi", ascending=False).head(50)
# Out:
#                                country  year  population  life_expectancy  \
# 1812                             Nauru  2013         NaN              NaN
# 1958                             Palau  2013       292.0              NaN
# 624                       Cook Islands  2013         NaN              NaN
# 1650                  Marshall Islands  2013         NaN              NaN
# 2713                            Tuvalu  2013      1819.0              NaN
# 1378                          Kiribati  2015     11247.0             66.3
# 1909                              Niue  2013         NaN              NaN
# 1379                          Kiribati  2014     11458.0             66.1
# 1380                          Kiribati  2013     18535.0             65.8
# 1381                          Kiribati  2012     16613.0             65.7
# 1382                          Kiribati  2011     14656.0             65.5
# 1383                          Kiribati  2010     12652.0             65.3
# ...

# %%
df_exp_2013 = df_exp.loc[df_exp.year == 2013]

# %%
df_exp_2013.shape
# Out:
# (193, 10)

# %%
sns.scatterplot(data=df_exp_2013, x="alcohol", y="life_expectancy")

# %%
sns.scatterplot(data=df_exp_2013, x="bmi", y="life_expectancy")

# %%
sns.scatterplot(data=df_exp_2013, x="total_expenditure", y="life_expectancy")

# %%
sns.regplot(data=df_exp_2013, x="total_expenditure", y="life_expectancy")

# %%
sns.regplot(data=df_exp_2013, x="percentage_expenditure", y="life_expectancy")

# %%
df_exp_2015.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-a37a433f1568> in <module>
# ----> 1 df_exp_2015.head(50)
#
# NameError: name 'df_exp_2015' is not defined
